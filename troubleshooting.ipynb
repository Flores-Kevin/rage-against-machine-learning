# %%
import requests
import json
from pprint import pprint
import pandas as pd
import time
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer
from sklearn.metrics.pairwise import cosine_similarity

#import spotify keys
from config import client_id
from config import client_secret

# %% [markdown]
# # Creating Access Token for Spotify API

# %%
def createToken():
    #generate access token for spotify api
    #from: https://stmorse.github.io/journal/spotify-api.html

    AUTH_URL = 'https://accounts.spotify.com/api/token'

    # POST
    auth_response = requests.post(AUTH_URL, {
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret,
    })

    # convert the response to JSON
    auth_response_data = auth_response.json()

    # save the access token
    access_token = auth_response_data['access_token']

    #In order to access, we send a properly formed GET request to the API server, with our access_token in the header. Let’s save this header info now, in the following very specific format:
    headers = {
        'Authorization': 'Bearer {token}'.format(token=access_token)
    }
    
    return headers

# %% [markdown]
# # Requesting Input from User
#
# (need to remember to use same variable names when saving user input from project page - search_track, search_artist, region)

# %%
# need to add instructions or code to remove punctuations for search to work
search_track = input("Please name a song: ").replace('"', '').replace("'", '').replace("!",'')
# Out:
# Please name a song:  as it was

# %%
search_artist = input("Please name that song's artist: ").replace('"', '').replace("'", '')
# Out:
# Please name that song's artist:  harry styles

# %%
# options for dropdown: ['Global', 'Vietnam', 'Venezuela', 'Uruguay', 'United Kingdom', 'Ukraine', 'UAE', 'Turkey', 'Thailand', 'Taiwan', 'Switzerland', 'Sweden', 'Spain', 'South Korea', 'South Africa', 'Slovakia', 'Singapore', 'Saudi Arabia', 'Romania', 'Portugal', 'Poland', 'Philippines', 'Peru', 'Paraguay', 'Panama', 'Pakistan', 'Norway', 'Nigeria', 'Nicaragua', 'New Zealand', 'Netherlands', 'Mexico', 'Malaysia', 'Luxembourg', 'Lithuania', 'Latvia', 'Kazakhstan', 'Japan', 'Italy', 'Israel', 'Ireland', 'Indonesia', 'Hungary', 'Hong Kong', 'Honduras', 'Guatemala', 'Greece', 'Germany', 'France', 'Finland', 'Estonia', 'El Salvador', 'Egypt', 'Ecuador', 'Dominican Republic', 'Denmark', 'Czech Republic', 'Cyprus', 'Costa Rica', 'Colombia', 'Chile', 'Canada', 'Bulgaria', 'Brazil', 'Bolivia', 'Belgium', 'Belarus', 'Austria', 'Australia', 'Argentina']
region = input("Please select a region: ")
# Out:
# Please select a region:  South Korea

# %% [markdown]
# # Function to Search for Matching Track Using Spotify API, Create DF of Track Features
#
# will be called/used within main function for recommending 5 new songs

# %%
def searchTrack(track,artist):
    #base URL for Spotify API search
    search_url = 'https://api.spotify.com/v1/search'
    
    # API search for track & artist input by user
    response = requests.get(search_url + '?q=track%3A' + search_track + '%20artist%3A' + search_artist + '&type=track%2Cartist&limit=1', headers=createToken()).json()
    
    # storing track id, artist, and track name from API search as variables
    track_id = response['tracks']['items'][0]["id"]
    artist_names = response['tracks']['items'][0]["artists"][0]['name']
    track_name = response['tracks']['items'][0]["name"]
    
    #base URL for Spotify API
    base_url = 'https://api.spotify.com/v1/'
    # API call to collect track features
    track_response = requests.get(base_url + 'audio-features/' + track_id, headers=createToken()).json()
    
    #empty lists to store song data retrieved from API call
    danceability = []
    energy = []
    # key = []
    loudness = []
    mode = []
    speechiness = []
    acousticness = []
    instrumentalness = []
    liveness = []
    valence = []
    tempo = []
    id_num = []
    # duration_mins = []
    # time_signature = []

    #fill in track info for each audio feature / empty list
    danceability.append(track_response["danceability"])
    energy.append(track_response["energy"])
    # key.append(track_response["key"])
    loudness.append(track_response["loudness"])
    mode.append(track_response["mode"])
    speechiness.append(track_response["speechiness"])
    acousticness.append(track_response["acousticness"])
    instrumentalness.append(track_response["instrumentalness"])
    liveness.append(track_response["liveness"])
    valence.append(track_response["valence"])
    tempo.append(track_response["tempo"])
    id_num.append(track_response["id"])
    # # duration recorded in api in milliseconds, converting to minutes here
    # duration_mins.append(round((track_response["duration_ms"] / 60000),2))
    # time_signature.append(track_response["time_signature"])    

    #create a dictionary to hold data gathered from the api
    track_dict = {
        "track_id": id_num,
        "artist_names": artist_names,
        "track_name": track_name,
        "danceability": danceability,
        "energy": energy,
        # "key": key,
        "loudness": loudness,
        "mode": mode,
        "speechiness": speechiness,
        "acousticness": acousticness,
        "instrumentalness": instrumentalness,
        "liveness": liveness,
        "valence": valence,
        "tempo": tempo,
        # "duration_mins": duration_mins,
        # "time_signature": time_signature,

    }
    #convert dictionary to a dataframe
    input_track_df = pd.DataFrame(track_dict)
    # input_track_df = input_track_df.drop(columns=['duration_mins'])
    return input_track_df

# %%
# test function
input_track_df = searchTrack(search_track,search_artist)
input_track_df
# Out:
#                  track_id  artist_names track_name  danceability  energy  \
# 0  4LRPiXqCikLlN15c3yImP7  Harry Styles  As It Was          0.52   0.731
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -5.338     0       0.0557         0.342           0.00101     0.311
#
#    valence   tempo
# 0    0.662  173.93

# %%
# test function
input_track_df = searchTrack(search_track,search_artist)
input_track_df
# Out:
#                  track_id artist_names track_name  danceability  energy  \
# 0  296nXCOv97WJNRWzIBQnoj  LE SSERAFIM   FEARLESS         0.863    0.62
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -7.167     1        0.135        0.0508           0.00324     0.129
#
#    valence    tempo
# 0    0.432  103.971

# %%
# test function
input_track_df = searchTrack(search_track,search_artist)
input_track_df
# Out:
#                  track_id artist_names track_name  danceability  energy  \
# 0  4GfK1qOF3uBWidbPlTCQRL        Tulus   Monokrom         0.534   0.462
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -9.383     1       0.0326         0.573          0.000006    0.0974
#
#    valence   tempo
# 0    0.519  88.046

# %%
# run function to create DF with input track and its audio features
user_track_df = searchTrack(search_track,search_artist)

#import CSVs created in "pulling_chart_track_features.ipynb" and save as individual dfs
features_csv_list = {"Global":"global_df.csv", "Vietnam":"vietnam_df.csv","Venezuela":"venezuela_df.csv",
"Uruguay":"uruguay_df.csv","United Kingdom":"united_kingdom_df.csv","Ukraine":"ukraine_df.csv",
"UAE":"uae_df.csv","Turkey":"turkey_df.csv","Thailand":"thailand_df.csv",
"Taiwan":"taiwan_df.csv","Switzerland":"switzerland_df.csv","Sweden":"sweden_df.csv",
"Spain":"spain_df.csv","South Korea":"south_korea_df.csv","South Africa":"south_africa_df.csv",
"Slovakia":"slovakia_df.csv","Singapore":"singapore_df.csv","Saudi Arabia":"saudi_arabia_df.csv",
"Romania":"romania_df.csv","Portugal":"portugal_df.csv","Poland":"poland_df.csv",
"Philippines":"philippines_df.csv","Peru":"peru_df.csv","Paraguay":"paraguay_df.csv",
"Panama":"panama_df.csv","Pakistan":"pakistan_df.csv","Norway":"norway_df.csv",
"Nigeria":"nigeria_df.csv","Nicaragua":"nicaragua_df.csv","New Zealand":"new_zealand_df.csv",
"Netherlands":"netherlands_df.csv","Mexico":"mexico_df.csv",
"Malaysia":"malaysia_df.csv","Luxembourg":"luxembourg_df.csv","Lithuania":"lithuania_df.csv",
"Latvia":"latvia_df.csv","Kazakhstan":"kazakhstan_df.csv","Japan":"japan_df.csv",
"Italy":"italy_df.csv","Israel":"israel_df.csv","Ireland":"ireland_df.csv",
"Indonesia":"indonesia_df.csv",
"Hungary":"hungary_df.csv","Hong Kong":"hong_kong_df.csv","Honduras":"honduras_df.csv",
"Guatemala":"guatemala_df.csv","Greece":"greece_df.csv","Germany":"germany_df.csv",
"France":"france_df.csv","Finland":"finland_df.csv","Estonia":"estonia_df.csv",
"El Salvador":"el_salvador_df.csv","Egypt":"egypt_df.csv","Ecuador":"ecuador_df.csv",
"Dominican Republic":"dominican_republic_df.csv","Denmark":"denmark_df.csv","Czech Republic":"czech_republic_df.csv",
"Cyprus":"cyprus_df.csv","Costa Rica":"costa_rica_df.csv","Colombia":"colombia_df.csv",
"Chile":"chile_df.csv","Canada":"canada_df.csv","Bulgaria":"bulgaria_df.csv",
"Brazil":"brazil_df.csv","Bolivia":"bolivia_df.csv","Belgium":"belgium_df.csv",
"Belarus":"belarus_df.csv","Austria":"austria_df.csv","Australia":"australia_df.csv",
"Argentina":"argentina_df.csv"}
# currently not working w/ api calls: "morocco":"morocco_df.csv","india":"india_df.csv","iceland":"iceland_df.csv"

d = {}

for key in features_csv_list:
    d[key] = pd.read_csv(f'resources/top_chart_features/{features_csv_list[key]}') 
    d[key] = d[key].drop(columns=['region','key','duration_mins','time_signature'])

selected_chart_df = d['South Korea']

# %%
# create combined df of the track features from the input track and all of the tracks from the selected regional chart
# row 0 will be the input song
combined_df = pd.concat([user_track_df,selected_chart_df.loc[:]]).reset_index(drop=True)    
combined_df
# Out:
#                    track_id                artist_names  \
# 0    4LRPiXqCikLlN15c3yImP7                Harry Styles
# 1    0a4MMyCrzT0En247IhqZbD                    NewJeans
# 2    5mdWIwsJAzR97ShGkt8gcR                ZICO, HOMIES
# 3    7gRFDGEzF9UkBV233yv2dc                   BLACKPINK
# 4    2gYj9lubBorOPIVWsTXugG                         IVE
# ..                      ...                         ...
# 196  03qu1u4hDyepQQi2lNxCka                   Lee Mujin
# 197  1xWVYPdaLm909DbFmuPGOR                     Sandeul
# 198  0U5HgFCn3EJN2zZqI0KGfJ                     Tophyun
# 199  4fFfyouye6vrX9o9z4PVMu                        Lauv
# 200  4qu63nuBpdn0qHUHuObEj1  Marshmello, Jonas Brothers
#
#                                          track_name  danceability  energy  \
# 0                                         As It Was         0.520   0.731
# 1                                          Hype Boy         0.593   0.935
# 2             New thing (Prod. ZICO) (Feat. Homies)         0.775   0.865
# 3                                         Shut Down         0.818   0.690
# 4                                        After LIKE         0.680   0.922
# ..                                              ...           ...     ...
# 196                                   Traffic light         0.609   0.717
# 197      Slightly Tipsy (She is My Type♡ X SANDEUL)         0.697   0.447
# 198                             Tell me you love me         0.716   0.557
# 199                                       Never Not         0.470   0.221
# 200  Leave Before You Love Me (with Jonas Brothers)         0.721   0.738
#
#      loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0      -5.338     0       0.0557       0.34200          0.001010    0.3110
# 1      -3.430     0       0.2250       0.26800          0.000000    0.2860
# 2      -2.015     1       0.3070       0.04530          0.000000    0.2610
# 3      -5.119     1       0.0454       0.00327          0.000000    0.1860
# 4      -1.215     1       0.1210       0.10300          0.000000    0.0877
# ..        ...   ...          ...           ...               ...       ...
# 196    -3.547     0       0.0597       0.09650          0.000000    0.0694
# 197    -6.552     1       0.0264       0.76900          0.000000    0.1150
# 198    -5.889     1       0.0308       0.77600          0.000000    0.1210
# 199    -9.243     1       0.0371       0.69300          0.000000    0.1040
# 200    -4.770     1       0.0403       0.00226          0.000004    0.1180
#
#      valence    tempo
# 0      0.662  173.930
# 1      0.783   99.976
# 2      0.663  175.120
# 3      0.688  110.071
# 4      0.799  125.014
# ..       ...      ...
# 196    0.545   97.026
# 197    0.549   93.931
# 198    0.625  106.986
# 199    0.264  133.714
# 200    0.637  119.976
#
# [201 rows x 13 columns]

# %%
# scale data (only features columns), create df of scaled data
scaler = StandardScaler()
# if using song_duration, needs to be combined_df.iloc[:, 3:16]
chart_scaled = scaler.fit_transform(combined_df.iloc[:, 3:13])
chart_scaled_df = pd.DataFrame(chart_scaled, columns=combined_df.iloc[:, 3:13].columns)
chart_scaled_df
# Out:
#      danceability    energy  loudness      mode  speechiness  acousticness  \
# 0       -0.904772  0.402887 -0.129001 -1.532971    -0.410229      0.203382
# 1       -0.386432  1.600247  0.820647 -1.532971     1.732061     -0.067792
# 2        0.905868  1.189388  1.524919  0.652328     2.769673     -0.883881
# 3        1.211191  0.162241 -0.020000  0.652328    -0.540563     -1.037901
# 4        0.231315  1.523944  1.923095  0.652328     0.416065     -0.672438
# ..            ...       ...       ...       ...          ...           ...
# 196     -0.272824  0.320715  0.762414 -1.532971    -0.359614     -0.696258
# 197      0.352025 -1.264026 -0.733232  0.652328    -0.780985      1.768133
# 198      0.486935 -0.618391 -0.403244  0.652328    -0.725309      1.793784
# 199     -1.259800 -2.590513 -2.072594  0.652328    -0.645590      1.489629
# 200      0.522438  0.443973  0.153704  0.652328    -0.605098     -1.041602
#
#      instrumentalness  liveness   valence     tempo
# 0           -0.082870  1.058591  0.520672  1.597697
# 1           -0.097737  0.851697  1.114383 -0.755781
# 2           -0.097737  0.644802  0.525579  1.635567
# 3           -0.097737  0.024119  0.648246 -0.434522
# 4           -0.097737 -0.789389  1.192890  0.041017
# ..                ...       ...       ...       ...
# 196         -0.097737 -0.940836 -0.053412 -0.849660
# 197         -0.097737 -0.563461 -0.033785 -0.948154
# 198         -0.097737 -0.513806  0.339124 -0.532698
# 199         -0.097737 -0.654494 -1.432196  0.317882
# 200         -0.097672 -0.538634  0.398004 -0.119310
#
# [201 rows x 10 columns]

# %%
# create array for input track data
array1 = chart_scaled_df.iloc[0,:].to_numpy().reshape(1, -1)
# create array for selected chart
array2 = chart_scaled_df.iloc[1:,:].to_numpy()

# run cosine similarity
cosine_sim = cosine_similarity(array1, array2)

# create list that is ranked by score, descending order
sim_scores = list(enumerate(cosine_sim[-1,:]))
sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

# create empty list to store recommendations
ranked_tracks = []

for i in range(0, 200):
    indx = sim_scores[i][0]
    ranked_tracks.append([combined_df['track_id'].iloc[indx], combined_df['artist_names'].iloc[indx], combined_df['track_name'].iloc[indx], sim_scores[i][1]])
#     np.round(sim_scores[i][1],decimals=5)
ranked_tracks
# Out:
# [['296nXCOv97WJNRWzIBQnoj', 'LE SSERAFIM', 'FEARLESS', 1.0],
#  ['2WTHLEVjfefbGoW7F3dXIg', 'aespa', 'Girls', 0.8002512289878987],
#  ['2DwUdMJ5uxv20EhAildreg', 'NewJeans', 'Cookie', 0.7198086013564983],
#  ['68EkhVWIeULhHxcbi1QhzK',
#   'AJR',
#   "World's Smallest Violin",
#   0.7187699750297063],
#  ['3LtpKP5abr2qqjunvjlX5i', 'Central Cee', 'Doja', 0.7077559040090882],
#  ['6UelLqGlWMcVH1E5c4H7lY',
#   'Harry Styles',
#   'Watermelon Sugar',
#   0.706978821434817],
#  ['3uKoBRThCMtgKss90CiXQc', 'ASH ISLAND', 'Nightmare', 0.6535625582919046],
#  ['0M4EDkH7RpbKlWwrZ9o17N', 'An Nyeong', 'haeyo (2022)', 0.6345643411673128],
#  ['56s2s5e8WuBsWVKnmz6J9L', 'STAYC', 'BEAUTIFUL MONSTER', 0.6329350953823673],
#  ['3gFcGnU4kTdMYLXDjH1TK8', 'STAYC', 'RUN2U', 0.6035582750929768],
#  ['6uEWYpv8HNAdbwHlqemG1F', 'BOL4', 'Love story', 0.5370469129496991],
#  ['4FKmrrI6y8REWoCyV5tAhY',
#   '10cm, BIG Naughty',
#   'Just 10 centimeters',
#   0.5319014258907724],
#  ['0CB3B5ir8I2KbB3dkGVtWF',
#   'WSG WANNBE (Gaya-G)',
#   'At That Moment',
#   0.5112979104914422],
#  ['3xWGA8pa0IKFI7IMPri4P0', 'Ed Sheeran', 'Shivers', 0.4908928442636219],
#  ['4iJprGt1rt5iy0sxXXaRWn',
#   'D-Hack, PATEKO',
#   'OHAYO MY NIGHT',
#   0.47461599259416987],
#  ['1Wwh6gmMeolwzbRzfZMY5b',
#   'BLACKPINK',
#   'Ready For Love',
#   0.46654722523681463],
#  ['5aucVLKiumD89mxVCB4zvS',
#   'Crush, j-hope',
#   'Rush Hour (Feat. j-hope of BTS)',
#   0.46309869921041696],
#  ['1oen3GpTcA486fTHaT7neg',
#   "Girls' Generation",
#   'FOREVER 1',
#   0.46130028644466076],
#  ['5cF0dROlMOK5uNZtivgu50', 'Charlie Puth', 'Attention', 0.4562626942860154],
#  ['6JeleVHUHrdvgiFESE33ZU', 'ASH ISLAND', 'MELODY', 0.4420267980721363],
#  ['27ZZdyTSQWI7Cug2d2PkqV',
#   'Armani White',
#   'BILLIE EILISH.',
#   0.43187961787054224],
#  ['2g0LdZQce9xlcHb1mBJyuz', 'IU', 'strawberry moon', 0.4302794824458923],
#  ['4bZZVcgWWMWPBwzTTp642w', 'BTS', 'Filter', 0.4280562026050368],
#  ['2SMq0lOqCTHayWa9juoI0d', 'Woo, Loco, GRAY', 'We Are', 0.4224264147048289],
#  ['3QwiidVHfeE9y5jl4n2MTC', 'SEVENTEEN', '_WORLD', 0.4220816135436454],
#  ['2D1xAiDD33nqcxtSMH30hO',
#   'Lim Young Woong',
#   'Love Station',
#   0.4136018452315415],
#  ['0O6u0VJ46W86TxN9wgyqDj',
#   'Post Malone, Doja Cat',
#   'I Like You (A Happier Song) (with Doja Cat)',
#   0.4128259595542448],
#  ['0QzuaeCEEOV40Pn7IvKEny', 'dhruv', 'double take', 0.412811631157195],
#  ['1dfsPqH09vnzUWEOsN98Ex', 'SEULGI', '28 Reasons', 0.410187987702614],
#  ['0UnOf7i44YK0ULpkEGHe4R', 'KyoungSeo', 'Dear my X', 0.40638411723213325],
#  ['365znJ27Fb3faGsctmQYWR', 'Lim Young Woong', 'Father', 0.40632162318405385],
#  ['0pYacDCZuRhcrwGUA5nTBe',
#   'IU, SUGA',
#   'eight(Prod.&Feat. SUGA of BTS)',
#   0.38716144701862265],
#  ['5rJ7bdPmr8nfmm2JQ8xHOz', 'NAYEON', 'POP!', 0.3831357184318662],
#  ['2ouguQxJZn4jXisuNREqe5',
#   'aespa',
#   "Life's Too Short (English Version)",
#   0.36439825762491784],
#  ['7n2FZQsaLb7ZRfRPfEeIvr', 'IVE', 'ELEVEN', 0.3635727884538408],
#  ['34lKiKHCKhMe9PAfGcdFNE', 'CHUNG HA', 'Sparkling', 0.3534989514533179],
#  ['4Cr43xPo7bwyCcL1g3yVCu',
#   'Lim Young Woong',
#   'A bientot',
#   0.3373520103048352],
#  ['6ex1Pz3pntgy4NPtxHXN2V', 'Ed Sheeran', 'Bad Habits', 0.336900029621916],
#  ['2RLdkXSaiQjRbey5pvP8Kt',
#   'Lim Young Woong',
#   'If We Ever Meet Again',
#   0.33324230914537345],
#  ['4Ws314Ylb27BVsvlZOy30C',
#   'BLACKPINK',
#   'Lovesick Girls',
#   0.32297981245185986],
#  ['6RBziRcDeiho3iTPdtEeg9', 'Younha', 'Event Horizon', 0.31966080286787335],
#  ['19Hg1UCZaCdpHB37L7x63X',
#   'The Black Skirts',
#   'EVERYTHING',
#   0.3140055839068191],
#  ['0VES0jpNQEdRpD31gYDIMe',
#   'Yoon Mirae, BIBI',
#   'LAW (Prod. Czaer)',
#   0.3047260631105705],
#  ['4LRPiXqCikLlN15c3yImP7', 'Harry Styles', 'As It Was', 0.30379297553320805],
#  ['50kpGaPAhYJ3sGmk6vplg0',
#   'Justin Bieber',
#   'Love Yourself',
#   0.30363334533883873],
#  ['0yfQBmmOIVqiwhV5u10EhN',
#   'Lim Young Woong',
#   'Love Letter',
#   0.29286176792792884],
#  ['2QWEMqQMJR1KDf6hDjJOs6', 'j-hope', 'Arson', 0.2831117775252366],
#  ['4zCIxSnVWpGNghERX4uWZF',
#   'YENA, BIBI',
#   'SMILEY(Feat. BIBI)',
#   0.27485793115730595],
#  ['20SIjymeaQNEv0NkPLpa6N',
#   'WSG WANNABE (Sa-Fire)',
#   'I Missed You',
#   0.25944948053257866],
#  ['0RErLzcXg9K3FtjN86e4gm', 'Grizzly', 'Beige coat', 0.244681539556615],
#  ['10qiH1RJkexhTUuN562FsP', 'Sion', 'Braindead', 0.23281577731576716],
#  ['2pIUpMhHL6L9Z5lnKxJJr9', 'NewJeans', 'Attention', 0.22172110280038365],
#  ['41HriGdYdajxCJIOMiIBWs',
#   'Kim Seungmin',
#   'My pleasure Is That You Ride The Bentley',
#   0.22025402095814298],
#  ['2zrhoHlFKxFTRF5aMyxMoQ', 'aespa', 'Next Level', 0.21814284450604096],
#  ['6wBpO4Xc4YgShnENGSFA1M', 'LE SSERAFIM', 'Sour Grapes', 0.21779619839848302],
#  ['7IuuFQShxmy7zMZ3vZvMFj',
#   'Lee Young Ji, Jay Park',
#   'Day & Night (feat. Jay Park)',
#   0.20917569811239406],
#  ['0L8LOav65XwLjCLS11gNPD', 'BLACKPINK', 'Typa Girl', 0.20786334974517834],
#  ['6HMtHNpW6YPi1hrw9tgF8P', 'Lizzo', 'About Damn Time', 0.20068549548025372],
#  ['2jidjmWNeRmKgLjXhW52Gz',
#   'Lim Young Woong',
#   'Our Blues, Our Life',
#   0.18404368662157508],
#  ['0HsRZwZzHoZ5AM5W2ZYI5c',
#   'BIG Naughty, 10cm',
#   'Beyond Love (Feat. 10CM)',
#   0.1777164281920649],
#  ['05STjz8kmPBUebu3uu5sO0', 'Lim Young Woong', 'Nest', 0.17382975887748306],
#  ['4YTvuLSqKshDOJvwyDmAYS',
#   'Sung Si Kyung',
#   'Every moment of you 너의 모든 순간',
#   0.16546051238285298],
#  ['2MJz8BxxMsERULatmBikDH', 'Pink Sweat$', 'At My Worst', 0.15660049447087127],
#  ['0kqTXMHiQiB7IECD0WwcPq', 'TWICE', 'Talk that Talk', 0.15434462653540815],
#  ['5PjdY0CKGZdEuoNab3yDmX',
#   'The Kid LAROI, Justin Bieber',
#   'STAY (with Justin Bieber)',
#   0.1442613541042856],
#  ['2BgEsaKNfHUdlh97KmvFyo', 'Anne-Marie', '2002', 0.14320105957779916],
#  ['1w2hClDL1xH4FPZIipZ1FJ',
#   'Yoon Do Hyun',
#   'I Guess I Loved You',
#   0.142014457192767],
#  ['3gAXVQOR0h7Ks71lsr5MFZ', 'BIBI', 'Animal Farm', 0.14094498728207525],
#  ['6jjYDGxVJsWS0a5wlVF5vS', 'BTS', 'Butter', 0.13842595870053187],
#  ['6I3mqTwhRpn34SLVafSH7G', 'Justin Bieber', 'Ghost', 0.1347783461600139],
#  ['5quFr5s5PXYfUX5jV2EBZ1',
#   'Jay Park, IU',
#   'GANADARA (Feat. IU)',
#   0.12854902388107955],
#  ['1E14FuM0BRaHAJSJ9YxMVu',
#   'Lim Young Woong',
#   'A Psalm of Life',
#   0.12621347050866652],
#  ['4KU23Zay3Q1W0c0yJCNczH', 'JANNABI', 'Baby I Need You', 0.11902967909144774],
#  ['7AdGloF1UHKe1vAZPbqIXH',
#   'BLACKPINK',
#   'The Happiest Girl',
#   0.11750271935004732],
#  ['10SRMwb9EuVS1K9rYsBfHQ', 'BTS', 'Yet To Come', 0.11452880863823249],
#  ['3AVXwaOGCEL8cmBecfcsFJ',
#   'Charlie Puth',
#   'Light Switch',
#   0.10982366043630294],
#  ['5nCwjUUsmBuNZKn9Xu10Os', 'IU', 'Celebrity', 0.0966978849070968],
#  ['3dbLT62Cvs46Ju7a8gpr36', 'aespa', 'Savage', 0.09559415348878288],
#  ['2bU2EvhMM4Z1M1CLJlnZH1',
#   '데이먼스 이어 Damons year',
#   'yours',
#   0.09030971249180016],
#  ['7rXcCpIAoOUCydkVDMcoPV', 'TAEYEON', 'INVU', 0.08149677015511263],
#  ['2P91MQbaiQOfbiz9VqhqKQ', 'Lauv', 'I Like Me Better', 0.08096942869303651],
#  ['5QM0SsyzmBM0pbFY52Xj1X',
#   'Sam Smith',
#   "I'm Not The Only One",
#   0.07993017935053143],
#  ['0mBP9X2gPCuapvpZ7TGDk3',
#   'Charlie Puth, Jung Kook, BTS',
#   'Left and Right (Feat. Jung Kook of BTS)',
#   0.07830964379769276],
#  ['0a4MMyCrzT0En247IhqZbD', 'NewJeans', 'Hype Boy', 0.06446747928338062],
#  ['2JIaYEoBsURkmNab7EgYwA',
#   'KANG MINKYUNG, CHOI JUNG HOON of JANNABI',
#   'Because we loved',
#   0.06179372733049128],
#  ['3bUD1FmJClHcD0U7rIN0TR',
#   'BIG Naughty, CHANGMO, Jay Park',
#   'Romance Symphony (Feat. CHANGMO, Jay Park)',
#   0.061779665642368135],
#  ['7pDDXE5HVFZBvMxjL4CjVp',
#   'NMIXX',
#   'COOL (Your rainbow)',
#   0.05630015117318453],
#  ['7GNRUsU3M4XNDDB9xle5Dz',
#   'PSY, SUGA',
#   'That That (prod. & feat. SUGA of BTS)',
#   0.055123517103313355],
#  ['0HYAsQwJIO6FLqpyTeD3l6',
#   'Fujii Kaze',
#   'Shinunoga E-Wa',
#   0.05136962332093122],
#  ['4k6Uh1HXdhtusDW5y8Gbvy', 'Steve Lacy', 'Bad Habit', 0.04955389735825028],
#  ['0y5iPq7pRaJV8iCGybWebp',
#   '21univ.',
#   'Sticker picture',
#   0.048444288888876925],
#  ['02MWAaffLxlfxAUY7c5dvx',
#   'Glass Animals',
#   'Heat Waves',
#   0.04481843167154582],
#  ['1oFAF1hdPOickyHgbuRjyX',
#   'The Weeknd, Ariana Grande',
#   'Save Your Tears (Remix) (with Ariana Grande) - Bonus Track',
#   0.041123523865927845],
#  ['7xTDT7gyIrv0xWpwwXExxU', 'Ed Sheeran', 'Celestial', 0.039502305736370834],
#  ['4zCcKPm03kHARVAiyzlDX8',
#   'Lim Young Woong',
#   'Trust in me',
#   0.027344452287418133],
#  ['1IvOxLYTstsq5Z6pN3l3zm',
#   'Lim Young Woong',
#   'Loving You',
#   0.01899316776400884],
#  ['5QDLhrAOJJdNAmCTJ8xMyW', 'BTS', 'Dynamite', 0.01652422722767435],
#  ['1qEmFfgcLObUfQm0j1W2CK',
#   'Harry Styles',
#   'Late Night Talking',
#   0.008662341283632516],
#  ['37YoRLUu1qId0ewavgvnkG',
#   'LE SSERAFIM',
#   'Blue Flame',
#   0.0061900766807399575],
#  ['4YaKlkNVJNbrIqN82EKFsQ',
#   'JANNABI',
#   'A thought on an autumn night',
#   0.005651175228067196],
#  ['2LBqCSwhJGcFQeTHMVGwy3',
#   'The Weeknd',
#   'Die For You',
#   0.0042715671254794415],
#  ['4JmRth9mDEINhUNIpDYLQi', 'JANNABI', 'Summer', 0.0016935137761510352],
#  ['4iJyoBOLtHqaGxP12qzhQI',
#   'Justin Bieber, Daniel Caesar, Giveon',
#   'Peaches (feat. Daniel Caesar & Giveon)',
#   -0.0032047781475528386],
#  ['76OGwb5RA9h4FxQPT33ekc', 'Rosa Linn', 'SNAP', -0.00832271416161925],
#  ['775S83AMYbQc8SYteOktTL', '10cm', 'Gradation', -0.008657871616628081],
#  ['3uA8SjMyDtwtt0jLPMQbVD',
#   'DEAN, Gaeko',
#   'D (Half Moon)',
#   -0.00969557483007589],
#  ['3XYRV7ZSHqIRDG87DKTtry',
#   'BTS',
#   'Permission to Dance',
#   -0.011486568850937953],
#  ['3pqgVtpnQbBAZoWT4AEm1B', 'fromis_9', 'Stay This Way', -0.01746122865174188],
#  ['2gYj9lubBorOPIVWsTXugG', 'IVE', 'After LIKE', -0.01780593781797277],
#  ['5xrtzzzikpG3BLbo4q1Yul', 'IU', 'LILAC', -0.025240092320613715],
#  ['5q3LwAHTqo9d3rET2EA9Nq',
#   '88rising, BIBI',
#   'The Weekend',
#   -0.03299858537176646],
#  ['396FqjKmViUZ92Wmm4rx3i', 'aespa', 'Illusion', -0.03430473010095251],
#  ['4rMEoXVYww6Xy7q9wSj4gy',
#   'Lim Young Woong',
#   'Love Always Run Away',
#   -0.038247746671852684],
#  ['4uUG5RXrOk84mYEfFvj3cK',
#   'David Guetta, Bebe Rexha',
#   "I'm Good (Blue)",
#   -0.057702643002100096],
#  ['186NCtNk1tUYS7c2DxgJ7O', 'V', 'Christmas Tree', -0.05927551602108386],
#  ['4nrDn3HEdKn524GrOSAll8',
#   'Charlie Puth',
#   'Charlie Be Quiet!',
#   -0.06956906694869569],
#  ['6I2tqFhk8tq69iursYxuxd', 'SEVENTEEN', 'HOT', -0.07185631763724457],
#  ['6C734SmqoIYuRWo2qSCnpC', 'NMIXX', 'DICE', -0.08438901418309333],
#  ['0U5HgFCn3EJN2zZqI0KGfJ',
#   'Tophyun',
#   'Tell me you love me',
#   -0.0846908535878075],
#  ['2yjlYDiNiQkdxVqTlaSrlX',
#   'Nicki Minaj',
#   'Super Freaky Girl',
#   -0.08527178584041369],
#  ['5BqwC9kOBbqYkzdOKeXFFk',
#   'JANNABI',
#   'for lovers who hesitate',
#   -0.09571525207650505],
#  ['0IGUXY4JbK18bu9oD4mPIm', '(G)I-DLE', 'TOMBOY', -0.11903062595604336],
#  ['3F5CgOj3wFlRv51JsHbxhe',
#   'Drake, 21 Savage',
#   'Jimmy Cooks (feat. 21 Savage)',
#   -0.13230170690914558],
#  ['66zdGutAO6NJmMjH8ejBIq', 'Christopher', 'Bad', -0.15240748002010818],
#  ['6LXIhiXK8z1KLd3giR904b',
#   'Charlie Puth',
#   'Smells Like Me',
#   -0.15518673570091596],
#  ['7gRFDGEzF9UkBV233yv2dc', 'BLACKPINK', 'Shut Down', -0.15556876653317003],
#  ['0VjIjW4GlUZAMYd2vXMi3b',
#   'The Weeknd',
#   'Blinding Lights',
#   -0.16031883069456682],
#  ['4Dr2hJ3EnVh2Aaot6fRwDO', 'IU', 'Blueming', -0.1623648018363555],
#  ['0CatzXH85XWyBqqdB6qPMB', 'NCT DREAM', 'Beatbox', -0.16595316528732867],
#  ['21jGcNKet2qwijlDFuPiPb', 'Post Malone', 'Circles', -0.1701055383845782],
#  ['68EMU2RD1ECNeOeJ5qAXCV',
#   'Charlie Puth, Selena Gomez',
#   "We Don't Talk Anymore (feat. Selena Gomez)",
#   -0.18594957854069866],
#  ['0Q5VnK2DYzRyfqQRJuUtvi', 'IVE', 'LOVE DIVE', -0.19687060537814552],
#  ['3oiMjDZ1bShIpFfOQf55IW', "BE'O", 'LOVE me', -0.19810058429959698],
#  ['5YMXGBD6vcYP7IolemyLtK', 'BTS', 'Euphoria', -0.200469512177309],
#  ['1XkMxUilV0E3ChDERZJUEq',
#   'Balming Tiger, Omega Sapien, bj wnjn, Mudd the student, RM',
#   'SEXY NUKIM (feat. RM of BTS)',
#   -0.20659578299767448],
#  ['2X45nVBeYzmDlrXji9Av0Q', 'MeloMance', 'Love, Maybe', -0.21346557660797985],
#  ['4h9wh7iOZ0GGn8QVp4RAOB',
#   'OneRepublic',
#   "I Ain't Worried",
#   -0.2216286334101334],
#  ['0RiRZpuVRbi7oqRdSMwhQY',
#   'Post Malone, Swae Lee',
#   'Sunflower - Spider-Man: Into the Spider-Verse',
#   -0.2232492393016593],
#  ['3T03rPwlL8NVk1yIaxeD8U',
#   'Justin Bieber',
#   'Off My Face',
#   -0.22554756818435415],
#  ['1m2PksrrMpIev63uPxT1V0', 'NMIXX', 'O.O', -0.23697612261906464],
#  ['56kfw7CKOCgcYqaoDU5o0B',
#   'DINDIN, 10cm',
#   'I’m not myself when I’m around you (Feat. 10CM)',
#   -0.2385374324908411],
#  ['7x3SGAkfIrzDr9paSslwMv',
#   'Lim Young Woong',
#   'Lovely Touch',
#   -0.23933168675706257],
#  ['2SLwbpExuoBDZBpjfefCtV', 'The Weeknd', 'Out of Time', -0.2608548207375992],
#  ['53NYRM8s4mm4yeCsmsvTik', 'ZICO', 'Freak', -0.275030259262226],
#  ['4p4yxplNCSmt9xfaAMpcd5', 'BIG Naughty', 'Vancouver', -0.2804409524854378],
#  ['5zwwW9Oq7ubSxoCGyW1nbY', 'BLACKPINK', 'Pink Venom', -0.28904059270504606],
#  ['2SSbQoEqPHu6qAgi3pFobY',
#   'Coogie, LeeHi',
#   'Alone (Feat. LeeHi)',
#   -0.3020186869369384],
#  ['0xzI1KAr0Yd9tv8jlIk3sn',
#   'benny blanco, BTS, Snoop Dogg',
#   'Bad Decisions (with BTS & Snoop Dogg)',
#   -0.3030794703572118],
#  ['4BLpd6QINAs4UXd1lVtdhj',
#   'Charlie Puth',
#   'Dangerously',
#   -0.31692997655494404],
#  ['6z1kLsntE7FuzKZHZWrXYN', 'DEAN', 'instagram', -0.32333247684678124],
#  ['1xWVYPdaLm909DbFmuPGOR',
#   'Sandeul',
#   'Slightly Tipsy (She is My Type♡ X SANDEUL)',
#   -0.3363522730669416],
#  ['1jIMjbzcGCcCQn5iMu9CUc',
#   'Charlie Puth',
#   "That's Hilarious",
#   -0.3773815388855623],
#  ['2oBMZYteeO8DyXV9gDx6Za',
#   'Red Velvet',
#   'Feel My Rhythm',
#   -0.3782103609206112],
#  ['69xohKu8C1fsflYAiSNbwM', 'BTS', 'Run BTS', -0.3850577369649444],
#  ['4fFfyouye6vrX9o9z4PVMu', 'Lauv', 'Never Not', -0.39454320422869094],
#  ['03qu1u4hDyepQQi2lNxCka', 'Lee Mujin', 'Traffic light', -0.4188444207260153],
#  ['07trPhWMgiagFnSOlmpzl0',
#   "BE'O, ZICO",
#   'Complex (Feat. ZICO)',
#   -0.4224110451333206],
#  ['6eyVKpe2LGukVfC8wpd3D2',
#   'Kim Seungmin, Punch',
#   'One, Two (Feat. Punch)',
#   -0.42282711331741474],
#  ['423WHvB4mKprM6hELzpH3F',
#   'Nerd Connection',
#   'Good Night Good Dream',
#   -0.4265950580535882],
#  ['6qmvAJSUfVGMubvI2awW7p', 'Tate McRae', 'uh oh', -0.42874709054538485],
#  ['4JmbtS0Muijl37KP9lDscy', 'SUNMI', 'Heart Burn', -0.43070678762199865],
#  ['5mdWIwsJAzR97ShGkt8gcR',
#   'ZICO, HOMIES',
#   'New thing (Prod. ZICO) (Feat. Homies)',
#   -0.43204787169492337],
#  ['7GARzfC1mwhDuk4t9WOACq', 'j-hope', 'MORE', -0.439483257257822],
#  ['6262LmmRM1khHX1D4yk6MA', 'Juho', 'without me', -0.44043070163028575],
#  ['4HBZA5flZLE435QTztThqH',
#   'Ariana Grande, Justin Bieber',
#   'Stuck with U (with Justin Bieber)',
#   -0.4469517197230828],
#  ['5IgjP7X4th6nMNDh4akUHb',
#   'Chris Brown',
#   'Under The Influence',
#   -0.4475989259295745],
#  ['1lUNlmwyhsJy6kXmmrO11t',
#   'SEUNGKWAN',
#   'As It Was - Spotify Singles',
#   -0.45020562464148933],
#  ['5Z9KJZvQzH6PFmb8SNkxuk',
#   'Lil Nas X, Jack Harlow',
#   'INDUSTRY BABY (feat. Jack Harlow)',
#   -0.45363916502812596],
#  ['4a9tbd947vo9K8Vti9JwcI',
#   'BTS, Halsey',
#   'Boy With Luv (feat. Halsey)',
#   -0.45662052960671634],
#  ['4LxFRsy3TZjqAtAgIsjkez',
#   'PATEKO, ASH ISLAND, Skinny Brown',
#   'Rainy day (Feat. ASH ISLAND, Skinny Brown)',
#   -0.47180278530808706],
#  ['7gXMkqirKU23zgdlSAb00a', "BE'O", 'Suddenly', -0.48387350245974325],
#  ['0zRezEuKtaAXHcB4eruwi2',
#   'Charlie Puth',
#   'I Don’t Think That I Like Her',
#   -0.5045677239111577],
#  ['38T0tPVZHcPZyhtOcCP7pF',
#   'Lil Nas X',
#   "STAR WALKIN' (League of Legends Worlds Anthem)",
#   -0.505101471141675],
#  ['3scRk3rUGIwpCg9kMNrtEQ', 'Baek A', 'Amor', -0.5090904948361861],
#  ['0bYVPJvXr8ACmw313cVvhB', 'BLACKPINK', 'Tally', -0.5172400616162395],
#  ['0tgxvf4rqBBeEB54h0nnRD',
#   'GyeongseoYeji, Jeon Gunho',
#   'If you lovingly call my name',
#   -0.517750735685001],
#  ['7CAdT0HdiQNlt1C7xk2hep',
#   'Jung Kook',
#   'Stay Alive (Prod. SUGA of BTS)',
#   -0.5292154180361367],
#  ['2gzhQaCTeNgxpeB2TPllyY',
#   'Jimin, HA SUNG WOON',
#   'With you',
#   -0.5457736306267923],
#  ['2xms6U7ngGDBYJ4RnRTPyz', '10cm', '스토커 Stalker', -0.556636942608953],
#  ['1WKLxJpDqkQ9x1qEDNutoX', 'NCT 127', '2 Baddies', -0.5574421844194696],
#  ['4h4QlmocP3IuwYEj2j14p8',
#   'Nicky Youre, dazy',
#   'Sunroof',
#   -0.5691605120999753],
#  ['6VhuP99TE6gYNQRJIlAWFD',
#   'Stephen Sanchez',
#   'Until I Found You',
#   -0.5729221927934808],
#  ['3MJhPqL2IgGs7gHEB2M35q', 'BLACKPINK', 'Hard to Love', -0.5803906617848447],
#  ['7IkuRNVAjwXpZ2DheQHL4L', 'EXID', 'FIRE', -0.5850422572380156],
#  ['1nX1b7kRg5a6XKAq7uQOpr', 'ITZY', 'SNEAKERS', -0.5852719654441163],
#  ['3TSLqZssCoCdDlMhCJ08XW', 'BIGBANG', 'Still Life', -0.6027717904940665],
#  ['2JzZzZUQj3Qff7wapcbKjc',
#   'Wiz Khalifa, Charlie Puth',
#   'See You Again (feat. Charlie Puth)',
#   -0.6080033598076081],
#  ['50xSycnGMDy0Wg5jJcOv3S', 'Lim Young Woong', 'Rainbow', -0.6118137284758467],
#  ['41CgzGD7xlgnJe14R4cqkL', 'Lauv', 'Paris in the Rain', -0.6152484043288843],
#  ['0e5UZadoZ5me957hKsxRYh', 'JVKE', 'golden hour', -0.6442917635741264],
#  ['26Iv7VGUF1lqU10rxQXFL8',
#   "Paul Blanco, BE'O",
#   'Summer (Feat. BE’O)',
#   -0.6548786307088235],
#  ['6xGruZOHLs39ZbVccQTuPZ', 'Joji', 'Glimpse of Us', -0.669280912796005],
#  ['0LMdtBOxbVgrYoA4n0Vwvv', 'IVE', 'ROYAL', -0.6696005783130429],
#  ['3nqQXoyQOWXiESFLlDF1hG',
#   'Sam Smith, Kim Petras',
#   'Unholy (feat. Kim Petras)',
#   -0.6808319559682385],
#  ['2lsRp40mCRkhqULWdMbOzn',
#   'Lim Young Woong',
#   'I Love You',
#   -0.6966602998474244],
#  ['2j1Es5qEl4pD8GEe2WsYgP', 'SEVENTEEN', 'Darl+ing', -0.7002585103591096],
#  ['4Dvkj6JhhA12EX05fT7y2e', 'Harry Styles', 'As It Was', -0.725351321630124],
#  ['46HNZY1i7O6jwTA7Slo2PI',
#   'Coldplay, BTS',
#   'My Universe',
#   -0.7731594874879179],
#  ['5y4WmuvFX1t3NdSId0MFOh',
#   'BLACKPINK',
#   'Yeah Yeah Yeah',
#   -0.8136858774064478],
#  ['5expoVGQPvXuwBBFuNGqBd', 'NewJeans', 'Hurt', -0.8942236730030282]]

# %% [markdown]
# # Function to Recommend 5 Tracks from Selected Top 200 Chart

# %%
def recommendSongs(track, artist, region):
    # run function to create DF with input track and its audio features
    user_track_df = searchTrack(track,artist)
    
    #import CSVs created in "pulling_chart_track_features.ipynb" and save as individual dfs
    features_csv_list = {"Global":"global_df.csv", "Vietnam":"vietnam_df.csv","Venezuela":"venezuela_df.csv",
    "Uruguay":"uruguay_df.csv","United Kingdom":"united_kingdom_df.csv","Ukraine":"ukraine_df.csv",
    "UAE":"uae_df.csv","Turkey":"turkey_df.csv","Thailand":"thailand_df.csv",
    "Taiwan":"taiwan_df.csv","Switzerland":"switzerland_df.csv","Sweden":"sweden_df.csv",
    "Spain":"spain_df.csv","South Korea":"south_korea_df.csv","South Africa":"south_africa_df.csv",
    "Slovakia":"slovakia_df.csv","Singapore":"singapore_df.csv","Saudi Arabia":"saudi_arabia_df.csv",
    "Romania":"romania_df.csv","Portugal":"portugal_df.csv","Poland":"poland_df.csv",
    "Philippines":"philippines_df.csv","Peru":"peru_df.csv","Paraguay":"paraguay_df.csv",
    "Panama":"panama_df.csv","Pakistan":"pakistan_df.csv","Norway":"norway_df.csv",
    "Nigeria":"nigeria_df.csv","Nicaragua":"nicaragua_df.csv","New Zealand":"new_zealand_df.csv",
    "Netherlands":"netherlands_df.csv","Mexico":"mexico_df.csv",
    "Malaysia":"malaysia_df.csv","Luxembourg":"luxembourg_df.csv","Lithuania":"lithuania_df.csv",
    "Latvia":"latvia_df.csv","Kazakhstan":"kazakhstan_df.csv","Japan":"japan_df.csv",
    "Italy":"italy_df.csv","Israel":"israel_df.csv","Ireland":"ireland_df.csv",
    "Indonesia":"indonesia_df.csv",
    "Hungary":"hungary_df.csv","Hong Kong":"hong_kong_df.csv","Honduras":"honduras_df.csv",
    "Guatemala":"guatemala_df.csv","Greece":"greece_df.csv","Germany":"germany_df.csv",
    "France":"france_df.csv","Finland":"finland_df.csv","Estonia":"estonia_df.csv",
    "El Salvador":"el_salvador_df.csv","Egypt":"egypt_df.csv","Ecuador":"ecuador_df.csv",
    "Dominican Republic":"dominican_republic_df.csv","Denmark":"denmark_df.csv","Czech Republic":"czech_republic_df.csv",
    "Cyprus":"cyprus_df.csv","Costa Rica":"costa_rica_df.csv","Colombia":"colombia_df.csv",
    "Chile":"chile_df.csv","Canada":"canada_df.csv","Bulgaria":"bulgaria_df.csv",
    "Brazil":"brazil_df.csv","Bolivia":"bolivia_df.csv","Belgium":"belgium_df.csv",
    "Belarus":"belarus_df.csv","Austria":"austria_df.csv","Australia":"australia_df.csv",
    "Argentina":"argentina_df.csv"}
    # currently not working w/ api calls: "morocco":"morocco_df.csv","india":"india_df.csv","iceland":"iceland_df.csv"

    d = {}

    for key in features_csv_list:
        d[key] = pd.read_csv(f'resources/top_chart_features/{features_csv_list[key]}') 
        d[key] = d[key].drop(columns=['region','key','duration_mins','time_signature'])

    selected_chart_df = d[region]
    
    # create combined df of the track features from the input track and all of the tracks from the selected regional chart
    # row 0 will be the input song
    combined_df = pd.concat([user_track_df,selected_chart_df.loc[:]]).reset_index(drop=True)    
    
    # scale data (only features columns), create df of scaled data
    scaler = StandardScaler()
    # if using song_duration, needs to be combined_df.iloc[:, 3:16]
    chart_scaled = scaler.fit_transform(combined_df.iloc[:, 3:13])
    chart_scaled_df = pd.DataFrame(chart_scaled, columns=combined_df.iloc[:, 3:13].columns)

    # create array for input track data
    array1 = chart_scaled_df.iloc[0,:].to_numpy().reshape(1, -1)
    # create array for selected chart
    array2 = chart_scaled_df.iloc[1:,:].to_numpy()

    # run cosine similarity
    cosine_sim = cosine_similarity(array1, array2)
    
    # create list that is ranked by score, descending order
    sim_scores = list(enumerate(cosine_sim[-1,:]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # create empty list to store recommendations
    ranked_tracks = []

    for i in range(0, 5):
        indx = sim_scores[i][0]
        ranked_tracks.append([combined_df['track_id'].iloc[indx], combined_df['artist_names'].iloc[indx], combined_df['track_name'].iloc[indx], np.round(sim_scores[i][1],decimals=2)])
    
    return ranked_tracks

# %%
recommendSongs(search_track,search_artist,region)
# Out:
# [['296nXCOv97WJNRWzIBQnoj', 'LE SSERAFIM', 'FEARLESS', 1.0],
#  ['2WTHLEVjfefbGoW7F3dXIg', 'aespa', 'Girls', 0.8],
#  ['2DwUdMJ5uxv20EhAildreg', 'NewJeans', 'Cookie', 0.72],
#  ['68EkhVWIeULhHxcbi1QhzK', 'AJR', "World's Smallest Violin", 0.72],
#  ['3LtpKP5abr2qqjunvjlX5i', 'Central Cee', 'Doja', 0.71]]

# %% [markdown]
# # (Keep cell below for testing track search)

# %%
#base URL for Spotify API search
search_url = 'https://api.spotify.com/v1/search'

response = requests.get(search_url + '?q=track%3A' + search_track + '%20artist%3A' + search_artist + '&type=track%2Cartist&limit=1', headers=createToken()).json()

pprint(response)

# track_id = response['tracks']['items'][0]["id"]
# artist_names = response['tracks']['items'][0]["artists"][0]['name']
# track_name = response['tracks']['items'][0]["name"]
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=track%3Asoul+man+artist%3Asam+&type=artist&offset=0&limit=1',
#              'items': [],
#              'limit': 1,
#              'next': None,
#              'offset': 0,
#              'previous': None,
#              'total': 0},
#  'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3Asoul+man+artist%3Asam+&type=track&offset=0&limit=1',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2BVYdY4PyfCF9z4NrkhEB2'},
#                                               'href': 'https://api.spotify.com/v1/artists/2BVYdY4PyfCF9z4NrkhEB2',
#                                               'id': '2BVYdY4PyfCF9z4NrkhEB2',
#                                               'name': 'Sam & Dave',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:2BVYdY4PyfCF9z4NrkhEB2'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AG',
#                                                        'AL',
#                                                        'AM',
#                                                        'AO',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'AZ',
#                                                        'BA',
#                                                        'BB',
#                                                        'BD',
#                                                        'BE',
#                                                        'BF',
#                                                        'BG',
#                                                        'BH',
#                                                        'BI',
#                                                        'BJ',
#                                                        'BN',
#                                                        'BO',
#                                                        'BR',
#                                                        'BS',
#                                                        'BT',
#                                                        'BW',
#                                                        'BY',
#                                                        'BZ',
#                                                        'CA',
#                                                        'CD',
#                                                        'CG',
#                                                        'CH',
#                                                        'CI',
#                                                        'CL',
#                                                        'CM',
#                                                        'CO',
#                                                        'CR',
#                                                        'CV',
#                                                        'CW',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DJ',
#                                                        'DK',
#                                                        'DM',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FJ',
#                                                        'FM',
#                                                        'FR',
#                                                        'GA',
#                                                        'GB',
#                                                        'GD',
#                                                        'GE',
#                                                        'GH',
#                                                        'GM',
#                                                        'GN',
#                                                        'GQ',
#                                                        'GR',
#                                                        'GT',
#                                                        'GW',
#                                                        'GY',
#                                                        'HK',
#                                                        'HN',
#                                                        'HR',
#                                                        'HT',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IQ',
#                                                        'IS',
#                                                        'IT',
#                                                        'JM',
#                                                        'JO',
#                                                        'JP',
#                                                        'KE',
#                                                        'KG',
#                                                        'KH',
#                                                        'KI',
#                                                        'KM',
#                                                        'KN',
#                                                        'KR',
#                                                        'KW',
#                                                        'KZ',
#                                                        'LA',
#                                                        'LB',
#                                                        'LC',
#                                                        'LI',
#                                                        'LK',
#                                                        'LR',
#                                                        'LS',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'LY',
#                                                        'MA',
#                                                        'MC',
#                                                        'MD',
#                                                        'ME',
#                                                        'MG',
#                                                        'MH',
#                                                        'MK',
#                                                        'ML',
#                                                        'MN',
#                                                        'MO',
#                                                        'MR',
#                                                        'MT',
#                                                        'MU',
#                                                        'MV',
#                                                        'MW',
#                                                        'MX',
#                                                        'MY',
#                                                        'MZ',
#                                                        'NA',
#                                                        'NE',
#                                                        'NG',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NP',
#                                                        'NR',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PG',
#                                                        'PH',
#                                                        'PK',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PW',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'RS',
#                                                        'RW',
#                                                        'SA',
#                                                        'SB',
#                                                        'SC',
#                                                        'SE',
#                                                        'SG',
#                                                        'SI',
#                                                        'SK',
#                                                        'SL',
#                                                        'SM',
#                                                        'SN',
#                                                        'SR',
#                                                        'ST',
#                                                        'SV',
#                                                        'SZ',
#                                                        'TD',
#                                                        'TG',
#                                                        'TH',
#                                                        'TJ',
#                                                        'TL',
#                                                        'TN',
#                                                        'TO',
#                                                        'TR',
#                                                        'TT',
#                                                        'TV',
#                                                        'TW',
#                                                        'TZ',
#                                                        'UA',
#                                                        'UG',
#                                                        'US',
#                                                        'UY',
#                                                        'UZ',
#                                                        'VC',
#                                                        'VE',
#                                                        'VN',
#                                                        'VU',
#                                                        'WS',
#                                                        'XK',
#                                                        'ZA',
#                                                        'ZM',
#                                                        'ZW'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/1DThdjKvkvxYaqlDUnQGzK'},
#                                  'href': 'https://api.spotify.com/v1/albums/1DThdjKvkvxYaqlDUnQGzK',
#                                  'id': '1DThdjKvkvxYaqlDUnQGzK',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273d526e12f9cf41ae9069660a8',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02d526e12f9cf41ae9069660a8',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851d526e12f9cf41ae9069660a8',
#                                              'width': 64}],
#                                  'name': 'Soul Men',
#                                  'release_date': '1967',
#                                  'release_date_precision': 'year',
#                                  'total_tracks': 11,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:1DThdjKvkvxYaqlDUnQGzK'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2BVYdY4PyfCF9z4NrkhEB2'},
#                                     'href': 'https://api.spotify.com/v1/artists/2BVYdY4PyfCF9z4NrkhEB2',
#                                     'id': '2BVYdY4PyfCF9z4NrkhEB2',
#                                     'name': 'Sam & Dave',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:2BVYdY4PyfCF9z4NrkhEB2'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AG',
#                                              'AL',
#                                              'AM',
#                                              'AO',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'AZ',
#                                              'BA',
#                                              'BB',
#                                              'BD',
#                                              'BE',
#                                              'BF',
#                                              'BG',
#                                              'BH',
#                                              'BI',
#                                              'BJ',
#                                              'BN',
#                                              'BO',
#                                              'BR',
#                                              'BS',
#                                              'BT',
#                                              'BW',
#                                              'BY',
#                                              'BZ',
#                                              'CA',
#                                              'CD',
#                                              'CG',
#                                              'CH',
#                                              'CI',
#                                              'CL',
#                                              'CM',
#                                              'CO',
#                                              'CR',
#                                              'CV',
#                                              'CW',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DJ',
#                                              'DK',
#                                              'DM',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FJ',
#                                              'FM',
#                                              'FR',
#                                              'GA',
#                                              'GB',
#                                              'GD',
#                                              'GE',
#                                              'GH',
#                                              'GM',
#                                              'GN',
#                                              'GQ',
#                                              'GR',
#                                              'GT',
#                                              'GW',
#                                              'GY',
#                                              'HK',
#                                              'HN',
#                                              'HR',
#                                              'HT',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IQ',
#                                              'IS',
#                                              'IT',
#                                              'JM',
#                                              'JO',
#                                              'JP',
#                                              'KE',
#                                              'KG',
#                                              'KH',
#                                              'KI',
#                                              'KM',
#                                              'KN',
#                                              'KR',
#                                              'KW',
#                                              'KZ',
#                                              'LA',
#                                              'LB',
#                                              'LC',
#                                              'LI',
#                                              'LK',
#                                              'LR',
#                                              'LS',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'LY',
#                                              'MA',
#                                              'MC',
#                                              'MD',
#                                              'ME',
#                                              'MG',
#                                              'MH',
#                                              'MK',
#                                              'ML',
#                                              'MN',
#                                              'MO',
#                                              'MR',
#                                              'MT',
#                                              'MU',
#                                              'MV',
#                                              'MW',
#                                              'MX',
#                                              'MY',
#                                              'MZ',
#                                              'NA',
#                                              'NE',
#                                              'NG',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NP',
#                                              'NR',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PG',
#                                              'PH',
#                                              'PK',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PW',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'RS',
#                                              'RW',
#                                              'SA',
#                                              'SB',
#                                              'SC',
#                                              'SE',
#                                              'SG',
#                                              'SI',
#                                              'SK',
#                                              'SL',
#                                              'SM',
#                                              'SN',
#                                              'SR',
#                                              'ST',
#                                              'SV',
#                                              'SZ',
#                                              'TD',
#                                              'TG',
#                                              'TH',
#                                              'TJ',
#                                              'TL',
#                                              'TN',
#                                              'TO',
#                                              'TR',
#                                              'TT',
#                                              'TV',
#                                              'TW',
#                                              'TZ',
#                                              'UA',
#                                              'UG',
#                                              'US',
#                                              'UY',
#                                              'UZ',
#                                              'VC',
#                                              'VE',
#                                              'VN',
#                                              'VU',
#                                              'WS',
#                                              'XK',
#                                              'ZA',
#                                              'ZM',
#                                              'ZW'],
#                        'disc_number': 1,
#                        'duration_ms': 159000,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USAT20001065'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/4eGHlplaq1ME8oetnTuFFf'},
#                        'href': 'https://api.spotify.com/v1/tracks/4eGHlplaq1ME8oetnTuFFf',
#                        'id': '4eGHlplaq1ME8oetnTuFFf',
#                        'is_local': False,
#                        'name': 'Soul Man',
#                        'popularity': 67,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/ff6fa3c6640cdcb2e958cacefd0d856f7dbf0a03?cid=c0c4fc4b0b4b46a8bdd83f2bcaa3657b',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:4eGHlplaq1ME8oetnTuFFf'}],
#             'limit': 1,
#             'next': 'https://api.spotify.com/v1/search?query=track%3Asoul+man+artist%3Asam+&type=track&offset=1&limit=1',
#             'offset': 0,
#             'previous': None,
#             'total': 141}}

# %% [markdown]
# # Reading in CSVs of Regional and Global Top 200 Charts

# %%
#import CSVs created in "pulling_chart_track_features.ipynb" and save as individual dfs
features_csv_list = {"Global":"global_df.csv", "Vietnam":"vietnam_df.csv","Venezuela":"venezuela_df.csv",
"Uruguay":"uruguay_df.csv","United Kingdom":"united_kingdom_df.csv","Ukraine":"ukraine_df.csv",
"UAE":"uae_df.csv","Turkey":"turkey_df.csv","Thailand":"thailand_df.csv",
"Taiwan":"taiwan_df.csv","Switzerland":"switzerland_df.csv","Sweden":"sweden_df.csv",
"Spain":"spain_df.csv","South Korea":"south_korea_df.csv","South Africa":"south_africa_df.csv",
"Slovakia":"slovakia_df.csv","Singapore":"singapore_df.csv","Saudi Arabia":"saudi_arabia_df.csv",
"Romania":"romania_df.csv","Portugal":"portugal_df.csv","Poland":"poland_df.csv",
"Philippines":"philippines_df.csv","Peru":"peru_df.csv","Paraguay":"paraguay_df.csv",
"Panama":"panama_df.csv","Pakistan":"pakistan_df.csv","Norway":"norway_df.csv",
"Nigeria":"nigeria_df.csv","Nicaragua":"nicaragua_df.csv","New Zealand":"new_zealand_df.csv",
"Netherlands":"netherlands_df.csv","Mexico":"mexico_df.csv",
"Malaysia":"malaysia_df.csv","Luxembourg":"luxembourg_df.csv","Lithuania":"lithuania_df.csv",
"Latvia":"latvia_df.csv","Kazakhstan":"kazakhstan_df.csv","Japan":"japan_df.csv",
"Italy":"italy_df.csv","Israel":"israel_df.csv","Ireland":"ireland_df.csv",
"Indonesia":"indonesia_df.csv",
"Hungary":"hungary_df.csv","Hong Kong":"hong_kong_df.csv","Honduras":"honduras_df.csv",
"Guatemala":"guatemala_df.csv","Greece":"greece_df.csv","Germany":"germany_df.csv",
"France":"france_df.csv","Finland":"finland_df.csv","Estonia":"estonia_df.csv",
"El Salvador":"el_salvador_df.csv","Egypt":"egypt_df.csv","Ecuador":"ecuador_df.csv",
"Dominican Republic":"dominican_republic_df.csv","Denmark":"denmark_df.csv","Czech Republic":"czech_republic_df.csv",
"Cyprus":"cyprus_df.csv","Costa Rica":"costa_rica_df.csv","Colombia":"colombia_df.csv",
"Chile":"chile_df.csv","Canada":"canada_df.csv","Bulgaria":"bulgaria_df.csv",
"Brazil":"brazil_df.csv","Bolivia":"bolivia_df.csv","Belgium":"belgium_df.csv",
"Belarus":"belarus_df.csv","Austria":"austria_df.csv","Australia":"australia_df.csv",
"Argentina":"argentina_df.csv"}
# currently not working w/ api calls: "morocco":"morocco_df.csv","india":"india_df.csv","iceland":"iceland_df.csv"

d = {}

for key in features_csv_list:
    d[key] = pd.read_csv(f'resources/top_chart_features/{features_csv_list[key]}') 
    d[key] = d[key].drop(columns=['region']) # try adding ",'duration_mins'" as well

# %%
regions_list = d.keys()
regions_list
# Out:
# dict_keys(['Global', 'Vietnam', 'Venezuela', 'Uruguay', 'United Kingdom', 'Ukraine', 'UAE', 'Turkey', 'Thailand', 'Taiwan', 'Switzerland', 'Sweden', 'Spain', 'South Korea', 'South Africa', 'Slovakia', 'Singapore', 'Saudi Arabia', 'Romania', 'Portugal', 'Poland', 'Philippines', 'Peru', 'Paraguay', 'Panama', 'Pakistan', 'Norway', 'Nigeria', 'Nicaragua', 'New Zealand', 'Netherlands', 'Mexico', 'Malaysia', 'Luxembourg', 'Lithuania', 'Latvia', 'Kazakhstan', 'Japan', 'Italy', 'Israel', 'Ireland', 'Indonesia', 'Hungary', 'Hong Kong', 'Honduras', 'Guatemala', 'Greece', 'Germany', 'France', 'Finland', 'Estonia', 'El Salvador', 'Egypt', 'Ecuador', 'Dominican Republic', 'Denmark', 'Czech Republic', 'Cyprus', 'Costa Rica', 'Colombia', 'Chile', 'Canada', 'Bulgaria', 'Brazil', 'Bolivia', 'Belgium', 'Belarus', 'Austria', 'Australia', 'Argentina'])

# %%
len(regions_list)
# Out:
# 70

# %%
dropdown_list = ['Global', 'Vietnam', 'Venezuela', 'Uruguay', 'United Kingdom', 'Ukraine', 'UAE', 'Turkey', 'Thailand', 'Taiwan', 'Switzerland', 'Sweden', 'Spain', 'South Korea', 'South Africa', 'Slovakia', 'Singapore', 'Saudi Arabia', 'Romania', 'Portugal', 'Poland', 'Philippines', 'Peru', 'Paraguay', 'Panama', 'Pakistan', 'Norway', 'Nigeria', 'Nicaragua', 'New Zealand', 'Netherlands', 'Mexico', 'Malaysia', 'Luxembourg', 'Lithuania', 'Latvia', 'Kazakhstan', 'Japan', 'Italy', 'Israel', 'Ireland', 'Indonesia', 'Hungary', 'Hong Kong', 'Honduras', 'Guatemala', 'Greece', 'Germany', 'France', 'Finland', 'Estonia', 'El Salvador', 'Egypt', 'Ecuador', 'Dominican Republic', 'Denmark', 'Czech Republic', 'Cyprus', 'Costa Rica', 'Colombia', 'Chile', 'Canada', 'Bulgaria', 'Brazil', 'Bolivia', 'Belgium', 'Belarus', 'Austria', 'Australia', 'Argentina']

# %%
dropdown_list.sort(reverse=False)

# %%
print(dropdown_list)
# Out:
# ['Argentina', 'Australia', 'Austria', 'Belarus', 'Belgium', 'Bolivia', 'Brazil', 'Bulgaria', 'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Cyprus', 'Czech Republic', 'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Estonia', 'Finland', 'France', 'Germany', 'Global', 'Greece', 'Guatemala', 'Honduras', 'Hong Kong', 'Hungary', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan', 'Latvia', 'Lithuania', 'Luxembourg', 'Malaysia', 'Mexico', 'Netherlands', 'New Zealand', 'Nicaragua', 'Nigeria', 'Norway', 'Pakistan', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Romania', 'Saudi Arabia', 'Singapore', 'Slovakia', 'South Africa', 'South Korea', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine', 'United Kingdom', 'Uruguay', 'Venezuela', 'Vietnam']
